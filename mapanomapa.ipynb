# %%
#hide
#!pip install -Uqq fastbook
import fastbook
fastbook.setup_book()
# Out:
# /home/juli/.local/lib/python3.8/site-packages/fastbook/__init__.py:18: UserWarning: Missing `graphviz` - please run `conda install fastbook`
#   except ModuleNotFoundError: warn("Missing `graphviz` - please run `conda install fastbook`")

# %%
#hide
from fastbook import *
from fastai.vision.widgets import *

# %%
dest = 'imagenes/mapa/An_updated_crustal_thickness_map_of_central_South_America_based_on_receiver_function_measurements_in_the_region_of_the_Chaco__Pantanal__and_Paraná_Basins__-22.jpg'
#download_url(ims[0], dest)

# %%
im = Image.open(dest)
im.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=91x128 at 0x7F96F2685CA0>

# %%
types = 'mapa','nomapa'
path = Path('imagenes')

# %%
if not path.exists():
    path.mkdir()
    for o in types:
        dest = (path/o)
        dest.mkdir(exist_ok=True)
        results = search_images_bing(key, f'{o} mapa')
        download_images(dest, urls=results.attrgot('contentUrl'))

# %%
fns = get_image_files(path)
fns
# Out:
# (#7809) [Path('imagenes/mapa/Ranging_Patterns_of_Two_Syntopic_Howler_Monkey_Species__Alouatta_guariba_and_A._caraya__in_Northeastern_Argentina-10.jpg'),Path('imagenes/mapa/Application_of_fuzzy_weight_of_evidence_and_data_mining_techniques_in_construction_of_flood_susceptibility_map_of_Poyang_County__China-03.jpg'),Path('imagenes/mapa/How_have_daily_climate_extremes_changed_in_the_recent_past_over_northeastern_Argentina_-33.jpg'),Path('imagenes/mapa/Hydrogeological_features_affecting_spatial_distribution_of_glyphosate_and_AMPA_in_groundwater_and_surface_water_in_an_agroecosystem._Córdoba__Argentina-38.jpg'),Path('imagenes/mapa/Complex_Geographical_Distribution_of_Ploidy_Levels_in_Polylepis_australis__Rosaceae___an_Endemic_Tree_Line_Species_in_Argentina-2.jpg'),Path('imagenes/mapa/Species_distribution_models_and_empirical_test__Comparing_predictions_with_well_understood_geographical_distribution_of_Bothrops_alternatus_in_Argentina-07.jpg'),Path('imagenes/mapa/Geographic_distribution_of
# ...

# %%
failed = verify_images(fns)
failed
# Out:
# (#0) []

# %%
failed.map(Path.unlink);

# %%
mapa = DataBlock(
    blocks=(ImageBlock, CategoryBlock), 
    get_items=get_image_files, 
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=parent_label,
    item_tfms=Resize(128))

# %%
dls = mapa.dataloaders(path)

# %%
dls.valid.show_batch(max_n=4, nrows=1)

# %%
mapa = mapa.new(item_tfms=Resize(128, ResizeMethod.Squish))
dls = mapa.dataloaders(path)
dls.valid.show_batch(max_n=4, nrows=1)

# %%
mapa = mapa.new(item_tfms=Resize(128, ResizeMethod.Pad, pad_mode='zeros'))
dls = mapa.dataloaders(path)
dls.valid.show_batch(max_n=4, nrows=1)

# %%
mapa = mapa.new(item_tfms=RandomResizedCrop(128, min_scale=0.3))
dls = mapa.dataloaders(path)
dls.train.show_batch(max_n=4, nrows=1, unique=True)

# %%
mapa = mapa.new(item_tfms=Resize(128), batch_tfms=aug_transforms(mult=2))
dls = mapa.dataloaders(path)
dls.train.show_batch(max_n=8, nrows=2, unique=True)
# Out:
# /home/juli/.local/lib/python3.8/site-packages/torch/_tensor.py:1023: UserWarning: torch.solve is deprecated in favor of torch.linalg.solveand will be removed in a future PyTorch release.
# torch.linalg.solve has its arguments reversed and does not return the LU factorization.
# To get the LU factorization see torch.lu, which can be used with torch.lu_solve or torch.lu_unpack.
# X = torch.solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve(A, B) (Triggered internally at  /pytorch/aten/src/ATen/native/BatchLinearAlgebra.cpp:760.)
#   ret = func(*args, **kwargs)

# %%
mapa = mapa.new(
    item_tfms=RandomResizedCrop(224, min_scale=0.5),
    batch_tfms=aug_transforms())
dls = mapa.dataloaders(path)
# Out:
# /home/juli/.local/lib/python3.8/site-packages/torch/_tensor.py:1023: UserWarning: torch.solve is deprecated in favor of torch.linalg.solveand will be removed in a future PyTorch release.
# torch.linalg.solve has its arguments reversed and does not return the LU factorization.
# To get the LU factorization see torch.lu, which can be used with torch.lu_solve or torch.lu_unpack.
# X = torch.solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve(A, B) (Triggered internally at  /pytorch/aten/src/ATen/native/BatchLinearAlgebra.cpp:760.)
#   ret = func(*args, **kwargs)

# %%
learn = cnn_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(4)
# Out:
# /home/juli/.local/lib/python3.8/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.692618</td>
#       <td>0.258678</td>
#       <td>0.073030</td>
#       <td>00:26</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
# ...

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()

# %%
interp.plot_top_losses(5, nrows=1)

# %%
#hide_output
cleaner = ImageClassifierCleaner(learn)
cleaner
# Out:
# <PIL.Image.Image image mode=RGBA size=84x128 at 0x7F96E8508CA0>
# <PIL.Image.Image image mode=RGBA size=99x128 at 0x7F96E8508D00>
# <PIL.Image.Image image mode=RGBA size=91x128 at 0x7F96E851AFD0>
# <PIL.Image.Image image mode=RGBA size=98x128 at 0x7F96E851AF40>
# <PIL.Image.Image image mode=RGBA size=100x128 at 0x7F96E852C0A0>
# <PIL.Image.Image image mode=RGBA size=84x128 at 0x7F96E851AD60>
# <PIL.Image.Image image mode=RGBA size=91x128 at 0x7F96E8508460>
# <PIL.Image.Image image mode=RGBA size=99x128 at 0x7F96E8508340>
# <PIL.Image.Image image mode=RGBA size=84x128 at 0x7F96E85083D0>
# <PIL.Image.Image image mode=RGBA size=84x128 at 0x7F96E85086D0>
# <PIL.Image.Image image mode=RGBA size=91x128 at 0x7F96E8508400>
# <PIL.Image.Image image mode=RGBA size=96x128 at 0x7F96E8508910>
# <PIL.Image.Image image mode=RGBA size=91x128 at 0x7F96E8508A30>
# <PIL.Image.Image image mode=RGBA size=84x128 at 0x7F96E8508F40>
# <PIL.Image.Image image mode=RGBA size=84x128 at 0x7F96E851AF70>
# ...

# %% [markdown]
# <img alt="Cleaner widget" width="700" src="images/att_00007.png">

# %%
#hide
for idx in cleaner.delete(): cleaner.fns[idx].unlink()
for idx,cat in cleaner.change(): shutil.move(str(cleaner.fns[idx]), path/cat)

# %%
learn.export()

# %%
path = Path()
path.ls(file_exts='.pkl')
# Out:
# (#1) [Path('export.pkl')]

# %%
learn_inf = load_learner(path/'export.pkl')

# %%
learn_inf.predict('imagenes/mapa/An_updated_crustal_thickness_map_of_central_South_America_based_on_receiver_function_measurements_in_the_region_of_the_Chaco__Pantanal__and_Paraná_Basins__-22.jpg')
# Out:
# ('mapa', tensor(0), tensor([9.9999e-01, 1.0583e-05]))

# %%
learn_inf.dls.vocab
# Out:
# ['mapa', 'nomapa']
